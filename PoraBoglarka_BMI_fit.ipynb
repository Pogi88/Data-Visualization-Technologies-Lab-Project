# %% [markdown]
# ## **BMI fit**
#
# **Készítette:** Póra Boglárka
#
# **Feladat:**
#
# Készítsetek (a saját és a kaggle adatokra is):
#
# eloszlás (hisztogram) diagramokat:
#
# * magasság
# * testsúly
# * BMI
#
# összefüggés (scatter plot) diagramokat:
#
# * magasság vs. testsúly
# * magasság vs. BMI
# * testsúly vs. BMI

# %% [markdown]
# ### **Könyvtárak és adatok importálása**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url_kaggle = 'https://raw.githubusercontent.com/vlewir/adatvizualizacio/refs/heads/main/BMI_fit_kaggle.csv'
url_own = 'https://raw.githubusercontent.com/vlewir/adatvizualizacio/refs/heads/main/BMI_fit_own.csv'
kaggle_data = pd.read_csv(url_kaggle)
own_data = pd.read_csv(url_own)

# %%
kaggle_data.head()
# Out:
#    ID  Magassag (m)  Suly (kg)    BMI
# 0   1          1.74         96  31.71
# 1   2          1.89         87  24.36
# 2   3          1.85        110  32.14
# 3   4          1.95        104  27.35
# 4   5          1.49         61  27.48

# %%
own_data.head()
# Out:
#    ID  Magassag (m)  Suly (kg)    BMI
# 0   1          1.85         94  27.47
# 1   2          1.60         50  19.53
# 2   3          1.76         65  20.98
# 3   4          1.86        102  29.48
# 4   5          1.89         76  21.28

# %% [markdown]
# ### **Színskála**

# %%
sns.set_style("white")
sns.set_palette("rocket")

# %%
sns.color_palette()
# Out:
# [(0.20973515, 0.09747934, 0.24238489),
#  (0.43860848, 0.12177004, 0.34119475),
#  (0.67824099, 0.09192342, 0.3504148),
#  (0.8833417, 0.19830556, 0.26014181),
#  (0.95381595, 0.46373781, 0.31769923),
#  (0.96516917, 0.70776351, 0.5606593)]

# %%
palette = sns.color_palette()

# %%
label_color = '#474747'

# %% [markdown]
# ### **Kaggle Adatok**

# %% [markdown]
# **Magasságok eloszlása**

# %%
plt.figure(figsize=(12, 6))

ax = sns.histplot(kaggle_data['Magassag (m)'], bins=30, kde=True, color=palette[0])

plt.title('Magasságok Eloszlása', color=label_color, fontsize=12)
plt.xlabel('Magasság (m)', color=label_color)
plt.ylabel('')

plt.gca().spines['bottom'].set_color(label_color)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

ax.tick_params(axis='x', colors=label_color)
ax.tick_params(axis='y', colors=label_color)

plt.show()

# %% [markdown]
# **Testsúlyok eloszlása**

# %%
plt.figure(figsize=(12, 6))
sns.histplot(kaggle_data['Suly (kg)'], bins=30, kde=True, color=palette[1])

plt.title('Testsúlyok Eloszlása', color=label_color, fontsize=12)
plt.xlabel('Testsúly (kg)', color=label_color)
plt.ylabel('')

plt.gca().spines['bottom'].set_color(label_color)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

ax.tick_params(axis='x', colors=label_color)
ax.tick_params(axis='y', colors=label_color)

plt.show()

# %% [markdown]
# **BMI eloszlása**

# %%
plt.figure(figsize=(12, 6))
sns.histplot(kaggle_data['BMI'], bins=30, kde=True, color=palette[2])

plt.title('BMI Eloszlása', color=label_color, fontsize=12)
plt.xlabel('BMI', color=label_color)
plt.ylabel('')

plt.gca().spines['bottom'].set_color(label_color)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

ax.tick_params(axis='x', colors=label_color)
ax.tick_params(axis='y', colors=label_color)

plt.show()

# %% [markdown]
# **Magasság vs. Testsúly**

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x=kaggle_data['Magassag (m)'], y=kaggle_data['Suly (kg)'], color=palette[3])
sns.regplot(x=kaggle_data['Magassag (m)'], y=kaggle_data['Suly (kg)'], scatter=False, color=palette[3], line_kws={'linewidth': 1})

plt.title('Magasság vs Testsúly', color=label_color, fontsize=12)
plt.xlabel('Magasság (m)', color=label_color)
plt.ylabel('Testsúly (kg)', color=label_color)

plt.gca().spines['left'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)

plt.gca().tick_params(axis='x', colors=label_color)
plt.gca().tick_params(axis='y', colors=label_color)

plt.show()

# %% [markdown]
# **Magasság vs. BMI**

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x=kaggle_data['Magassag (m)'], y=kaggle_data['BMI'], color=palette[4])
sns.regplot(x=kaggle_data['Magassag (m)'], y=kaggle_data['BMI'], scatter=False, color=palette[4], line_kws={'linewidth': 1})

plt.title('Magasság vs BMI', color=label_color, fontsize=12)
plt.xlabel('Magasság (m)', color=label_color)
plt.ylabel('BMI', color=label_color)

plt.gca().spines['left'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)

ax.tick_params(axis='x', colors=label_color)
ax.tick_params(axis='y', colors=label_color)

plt.show()

# %% [markdown]
# **Testsúly vs. BMI**

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x=kaggle_data['Suly (kg)'], y=kaggle_data['BMI'], color=palette[5])
sns.regplot(x=kaggle_data['Suly (kg)'], y=kaggle_data['BMI'], scatter=False, color=palette[5], line_kws={'linewidth': 1})

plt.title('Testsúly vs BMI', color=label_color, fontsize=12)
plt.xlabel('Testsúly (kg)', color=label_color)
plt.ylabel('BMI', color=label_color)

plt.gca().spines['left'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)

ax.tick_params(axis='x', colors=label_color)
ax.tick_params(axis='y', colors=label_color)

plt.show()

# %% [markdown]
# ### **Saját Adatok**

# %% [markdown]
# **Magasságok eloszlása**

# %%
plt.figure(figsize=(12, 6))
sns.histplot(own_data['Magassag (m)'], bins=30, kde=True, color=palette[0])

plt.title('Magasságok Eloszlása', color=label_color, fontsize=12)
plt.xlabel('Magasság (m)', color=label_color)
plt.ylabel('')

plt.gca().spines['bottom'].set_color(label_color)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

ax.tick_params(axis='x', colors=label_color)
ax.tick_params(axis='y', colors=label_color)

plt.show()

# %% [markdown]
# **Testsúlyok eloszlása**

# %%
plt.figure(figsize=(12, 6))
sns.histplot(own_data['Suly (kg)'], bins=30, kde=True, color=palette[1])

plt.title('Testsúlyok Eloszlása', color=label_color, fontsize=12)
plt.xlabel('Testsúly (kg)', color=label_color)
plt.ylabel('')

plt.gca().spines['bottom'].set_color(label_color)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

ax.tick_params(axis='x', colors=label_color)
ax.tick_params(axis='y', colors=label_color)

plt.show()

# %% [markdown]
# **BMI eloszlása**

# %%
plt.figure(figsize=(12, 6))
sns.histplot(own_data['BMI'], bins=30, kde=True, color=palette[2])

plt.title('BMI Eloszlása', color=label_color, fontsize=12)
plt.xlabel('BMI', color=label_color)
plt.ylabel('')

plt.gca().spines['bottom'].set_color(label_color)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

ax.tick_params(axis='x', colors=label_color)
ax.tick_params(axis='y', colors=label_color)

plt.show()

# %% [markdown]
# **Magasság vs. Testsúly**

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x=own_data['Magassag (m)'], y=own_data['Suly (kg)'], color=palette[3])
sns.regplot(x=own_data['Magassag (m)'], y=own_data['Suly (kg)'], scatter=False, color=palette[3], line_kws={'linewidth': 1})

plt.title('Magasság vs Testsúly', color=label_color, fontsize=12)
plt.xlabel('Magasság (m)', color=label_color)
plt.ylabel('Testsúly (kg)', color=label_color)

plt.gca().spines['left'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)

ax.tick_params(axis='x', colors=label_color)
ax.tick_params(axis='y', colors=label_color)

plt.show()

# %% [markdown]
# **Magasság vs. BMI**

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x=own_data['Magassag (m)'], y=own_data['BMI'], color=palette[4])
sns.regplot(x=own_data['Magassag (m)'], y=own_data['BMI'], scatter=False, color=palette[4], line_kws={'linewidth': 1})

plt.title('Magasság vs BMI', color=label_color, fontsize=12)
plt.xlabel('Magasság (m)', color=label_color)
plt.ylabel('BMI')

plt.gca().spines['left'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)

ax.tick_params(axis='x', colors=label_color)
ax.tick_params(axis='y', colors=label_color)

plt.show()

# %% [markdown]
# **Testsúly vs. BMI**

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x=own_data['Suly (kg)'], y=own_data['BMI'], color=palette[5])
sns.regplot(x=own_data['Suly (kg)'], y=own_data['BMI'], scatter=False, color=palette[5], line_kws={'linewidth': 1})

plt.title('Testsúly vs BMI', color=label_color, fontsize=12)
plt.xlabel('Testsúly (kg)', color=label_color)
plt.ylabel('BMI')

plt.gca().spines['left'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)

ax.tick_params(axis='x', colors=label_color)
ax.tick_params(axis='y', colors=label_color)

plt.show()
